# %% [markdown]
# # Double-Q learning project

# %% [markdown]
# Credit to the reinforcement learning homework, which I used a starting point for this project.

# %%
import torch
from torch import nn, optim
import numpy as np
import matplotlib.pyplot as plt
import random
from tqdm.notebook import tqdm
import gymnasium as gym

# %%
device = 'cpu'
if torch.cuda.is_available():
    device = 'cuda:1'
elif torch.backends.mps.is_available():
    device = 'mps'
print(device)

# %%
env = gym.wrappers.AtariPreprocessing(gym.make("ALE/Frogger-v5"), frame_skip = 1)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %%
env.observation_space
# Out:
# Box(0, 255, (84, 84), uint8)

# %% [markdown]
# # Network and Training Function code

# %%
class QNetwork(nn.Module):

    def __init__(self, state_dim, num_actions):
        super().__init__()
        # We use a convolutional model as our input is the video output of the atari game
        self.model = nn.Sequential(
            nn.Conv2d(1, 32, 8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, num_actions)
        )

    def forward(self, x):
        # Run your model on x. This should return a Q value for each action.
        return self.model(x)
        


class ReplayMemory:

    def __init__(self, cap, evict_oldest=False):
        self.capacity = cap
        self.data = []
        self.evict_oldest = evict_oldest
        if self.evict_oldest:
            self.oldest = 0

    def push(self, state, action, reward, nstate, term):
        if len(self.data) < self.capacity:
            self.data.append((state, action, reward, nstate, term))
        else:
            if self.evict_oldest:
                idx = self.oldest
                self.oldest = (self.oldest + 1) % self.capacity
            else:
                idx = random.randint(0, self.capacity - 1)
            self.data[idx] = (state, action, reward, nstate, term)

    def sample(self, batch_size):
        return random.sample(self.data, batch_size)

    def __len__(self):
        return len(self.data)

    def empty(self):
        self.data = []
        if self.evict_oldest:
            self.oldest = 0

# %%
def train_q_learning(env, gamma=0.99, lr=2.5e-4, tau=0.01, batch_size=32, num_interactions=10000, eps=0.1, double=False, linear_eps_decay = 1000000, starting_network = None, iteration = 0):
    actionspace = 5
    statespace = (84,84)
    if starting_network == None:
        policy_network = QNetwork(statespace, actionspace).to(device)
    else:
        policy_network = QNetwork(statespace, actionspace)
        policy_network.load_state_dict(torch.load(starting_network))
        policy_network.to(device)
        policy_network.train()
    target_network = QNetwork(statespace, actionspace).to(device)
    target_network.load_state_dict(policy_network.state_dict())

    replay_buffer = ReplayMemory(1000000)

    opt = optim.Adam(policy_network.parameters(), lr=lr)
    loss = nn.SmoothL1Loss()
    rng = np.random.default_rng()
    last_save = 0
    state, _ = env.reset()
    
    state = state[np.newaxis]
    
    eps_goal = eps
    ep_r = 0
    ep_rewards = []
    for i in tqdm(range(num_interactions)):
        
        # Choose a random action with probability eps, otherwise take the best
        # action according to the policy network.
        if i <= linear_eps_decay:
            eps = 1 - i * ((1 - eps_goal) / linear_eps_decay)
            
        if rng.random() <= eps:
            action = torch.randint(low = 0, high = actionspace, size = (1,), device = device).max()

        else:
            action = policy_network(torch.tensor(state, dtype=torch.float, device = device).unsqueeze(dim=0)).argmax()
 
        # Take a step in the environment, add the transition to the replay
        # buffer, and add the reward to ep_r

        nstate, reward, term, trunc, _ = env.step(action)
        nstate = nstate[np.newaxis]
        replay_buffer.push(state, action, reward, nstate, term)
        state = nstate
        ep_r += reward
        if len(replay_buffer) >= batch_size:
            batch = replay_buffer.sample(batch_size)
            st_batch, act_batch, r_batch, nst_batch, t_batch = zip(*batch)
            st_batch = torch.tensor(np.array(st_batch), device = device).float()

            act_batch = torch.tensor(act_batch, device = device).unsqueeze(dim=1)

            r_batch = torch.tensor(np.array(r_batch), device = device).float()
            nst_batch = torch.tensor(np.array(nst_batch), device = device).float()
            t_batch = torch.tensor(np.array(t_batch), device = device)
            
            # Evaluate the policy network on st_batch and choose Q values
            # corresponding to actions in act_batch. These is your predicted
            # Q values.
            pred_vals = policy_network(st_batch).gather(1, act_batch).squeeze()

            # Evaluate the target network on nst_batch and take the maximum
            # over actions. For every element where t_batch is True, set this
            # value to zero.
            if double == False:
                pred_next_vals = target_network(nst_batch).max(dim=1).values
            else:
                # In deep double Q learning, we use the target network as the secondary network for convience and speed.
                # By taking the lower of the two estimates, we mitigate the inherent overestimation of taking maximal action in the Q-Network.
                target_pred = target_network(nst_batch).max(dim=1).values
                policy_pred = policy_network(nst_batch).max(dim=1).values

                pred_next_vals = torch.stack((target_pred, policy_pred)).min(dim = 0).values
  
            pred_next_vals[t_batch] = 0

            # Compute the expected Q value (the right hand side of our loss
            # above) using the target network values you just computed and
            # r_batch.
            expected_q = r_batch + gamma * pred_next_vals

            # Apply loss to your predicted Q values and expected Q values.
            loss_val = loss(pred_vals, expected_q)

            # Take an optimization step
            opt.zero_grad()
            loss_val.backward()
            opt.step()

        p_state_dict = policy_network.state_dict()
        t_state_dict = target_network.state_dict()
        for key in p_state_dict:
            t_state_dict[key] = p_state_dict[key] * tau + t_state_dict[key] * (1 - tau)
        target_network.load_state_dict(t_state_dict)
        
        last_save += 1
        if term or trunc:
            ep_rewards.append(ep_r)
            if last_save >= 250000:
                torch.save(policy_network.state_dict(), "./models3/modelr" + str(int(ep_r)) + "e" + str(iteration) + ".pt")
                last_save = 0
                iteration += 1
            state, _ = env.reset()
            state = state[np.newaxis]
            ep_r = 0 
        
    return policy_network, ep_rewards

# %% [markdown]
# # Training

# %% [markdown]
# Because I was training remotely using a vpn, I couldn't train for the full number of iterations before the vpn timed out.
# To get around this I saved the model regularly and loaded the most recent one when restarting the training.
# I didn't forsee this so unfortunately I didn't record the epoch when saving at first, so I don't have a graph of how training went.

# %%
q_policy, q_returns = train_q_learning(env, lr=2.5e-4, num_interactions=40000000, double = False, starting_network = "./models3/modelr23e4.pt", iteration = 97, linear_eps_decay = -1)
# Out:
#   0%|          | 0/40000000 [00:00<?, ?it/s]

# %%
d_policy, d_returns = train_q_learning(env, lr=2.5e-4, num_interactions=40000000, double = True, starting_network = "./models2/model33.pt", linear_eps_decay = -1)
# Out:
#   0%|          | 0/40000000 [00:00<?, ?it/s]

# %% [markdown]
# # Testing and Visualization

# %%
rewardsum1 = 0
rewardsum2 = 0
rewardsum3 = 0

# %%
load_device = torch.device('cpu')
model = QNetwork((84,84), 5)
model.load_state_dict(torch.load("./models2/model39.pt", map_location=load_device))
model.eval()
# Out:
# QNetwork(
#   (model): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=3136, out_features=5, bias=True)
#   )
# )

# %%
envObserve = gym.wrappers.AtariPreprocessing(gym.make("ALE/Frogger-v5"), frame_skip = 1)

state, info = envObserve.reset()
state = state[np.newaxis]

for _ in range(21600):
    action = model(torch.tensor(state, dtype=torch.float).unsqueeze(dim=0)).argmax() # agent policy; take the best predicted reward of the Q-network
    # print(action)
    state, reward, terminated, truncated, info = envObserve.step(action)
    rewardsum1 += reward
    state = state[np.newaxis]
    if terminated or truncated:
        state, info = envObserve.reset()
        state = state[np.newaxis]
print(rewardsum1)
envObserve.close()
# Out:
# 1714.0

# %%
load_device = torch.device('cpu')
model = QNetwork((84,84), 5)
model.load_state_dict(torch.load("./models3/modelr23e4.pt", map_location=load_device))
model.eval()
# Out:
# QNetwork(
#   (model): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=3136, out_features=5, bias=True)
#   )
# )

# %%
envObserve = gym.wrappers.AtariPreprocessing(gym.make("ALE/Frogger-v5"), frame_skip = 1)

state, info = envObserve.reset()
state = state[np.newaxis]

for _ in range(21600):
    action = model(torch.tensor(state, dtype=torch.float).unsqueeze(dim=0)).argmax() # agent policy; take the best predicted reward of the Q-network
    # print(action)
    state, reward, terminated, truncated, info = envObserve.step(action)
    rewardsum2 += reward
    state = state[np.newaxis]
    if terminated or truncated:
        state, info = envObserve.reset()
        state = state[np.newaxis]
print(rewardsum2)
envObserve.close()
# Out:
# 1429.0

# %%
envObserve = gym.wrappers.AtariPreprocessing(gym.make("ALE/Frogger-v5"), frame_skip = 1)

state, info = envObserve.reset()
state = state[np.newaxis]
rng = np.random.default_rng()
for _ in range(21600):
    action =  rng.integers(0, high = 5)
    
    state, reward, terminated, truncated, info = envObserve.step(action)
    rewardsum3 += reward
    state = state[np.newaxis]
    if terminated or truncated:
        state, info = envObserve.reset()
        state = state[np.newaxis]
print(rewardsum3)
envObserve.close()
# Out:
# 704.0

# %%
fig, ax = plt.subplots()

policies = ['Double Deep Q-Network', 'Deep Q-Network', 'Random Action']
counts = [rewardsum1, rewardsum2, rewardsum3]
bar_colors = ['tab:red', 'tab:blue', 'tab:orange']

ax.bar(policies, counts, color=bar_colors)

ax.set_ylabel('Reward (game score)')
ax.set_title('Reward earned by policy in 30 minutes of playtime')


plt.show()

# %% [markdown]
# Let's see how the policies compare when they are only allowed one episode.

# %%
rewardsum1 = 0
rewardsum2 = 0
rewardsum3 = 0

# %%
load_device = torch.device('cpu')
model = QNetwork((84,84), 5)
model.load_state_dict(torch.load("./models2/model39.pt", map_location=load_device))
model.eval()
# Out:
# QNetwork(
#   (model): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=3136, out_features=5, bias=True)
#   )
# )

# %%
envObserve = gym.wrappers.AtariPreprocessing(gym.make("ALE/Frogger-v5"), frame_skip = 1)

state, info = envObserve.reset()
state = state[np.newaxis]
for _ in range(100):
    for _ in range(21600):
        action = model(torch.tensor(state, dtype=torch.float).unsqueeze(dim=0)).argmax() # agent policy; take the best predicted reward of the Q-network
        # print(action)
        state, reward, terminated, truncated, info = envObserve.step(action)
        rewardsum1 += reward
        state = state[np.newaxis]
        if terminated or truncated:
            state, info = envObserve.reset()
            state = state[np.newaxis]
            break
print(rewardsum1)
envObserve.close()
# Out:
# 3487.0

# %%
load_device = torch.device('cpu')
model = QNetwork((84,84), 5)
model.load_state_dict(torch.load("./models3/modelr23e4.pt", map_location=load_device))
model.eval()
# Out:
# QNetwork(
#   (model): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=3136, out_features=5, bias=True)
#   )
# )

# %%
envObserve = gym.wrappers.AtariPreprocessing(gym.make("ALE/Frogger-v5"), frame_skip = 1)

state, info = envObserve.reset()
state = state[np.newaxis]
for _ in range(100):
    for _ in range(21600):
        action = model(torch.tensor(state, dtype=torch.float).unsqueeze(dim=0)).argmax() # agent policy; take the best predicted reward of the Q-network
        # print(action)
        state, reward, terminated, truncated, info = envObserve.step(action)
        rewardsum2 += reward
        state = state[np.newaxis]
        if terminated or truncated:
            state, info = envObserve.reset()
            state = state[np.newaxis]
            break
print(rewardsum2)
envObserve.close()
# Out:
# 1873.0

# %%
envObserve = gym.wrappers.AtariPreprocessing(gym.make("ALE/Frogger-v5"), frame_skip = 1)

state, info = envObserve.reset()
state = state[np.newaxis]
rng = np.random.default_rng()
for _ in range(100):
    for _ in range(21600):
        action =  rng.integers(0, high = 5)
        
        state, reward, terminated, truncated, info = envObserve.step(action)
        rewardsum3 += reward
        state = state[np.newaxis]
        if terminated or truncated:
            state, info = envObserve.reset()
            state = state[np.newaxis]
            break
print(rewardsum3)
envObserve.close()
# Out:
# 915.0

# %%
rewardsum1 = rewardsum1 / 100
rewardsum2 = rewardsum2 / 100
rewardsum3 = rewardsum3 / 100

# %%
fig, ax = plt.subplots()

policies = ['Double Deep Q-Network', 'Deep Q-Network', 'Random Action']
counts = [rewardsum1, rewardsum2, rewardsum3]
bar_colors = ['tab:red', 'tab:blue', 'tab:orange']

ax.bar(policies, counts, color=bar_colors)

ax.set_ylabel('Reward (game score)')
ax.set_title('Reward earned by policy in 1 game (averaged over 100 games)')


plt.show()

# %% [markdown]
# Here the double Q-network performs better than before.
# My hypothesis is that a more agressive policy can score you more points over a period of time,
# but the less overoptimistic double Q-network is better at longevity when given a set amount of lives instead of a set amount of time.

# %% [markdown]
# For fun, lets see how our best network is actually playing frogger using Gymnasium's visualization tools.

# %%
load_device = torch.device('cpu')
model = QNetwork((84,84), 5)
model.load_state_dict(torch.load("./models2/model39.pt", map_location=load_device))
model.eval()
# Out:
# QNetwork(
#   (model): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=3136, out_features=5, bias=True)
#   )
# )

# %%
envObserve = gym.wrappers.AtariPreprocessing(gym.make("ALE/Frogger-v5", repeat_action_probability= 0), frame_skip = 1, noop_max= 0)
envAct = gym.make("ALE/Frogger-v5", render_mode = "human", repeat_action_probability= 0)
envAct.reset()
state, info = envObserve.reset()
state = state[np.newaxis]
rng = np.random.default_rng()

for _ in range(21600):
    action =  model(torch.tensor(state, dtype=torch.float).unsqueeze(dim=0)).argmax() # agent policy; take the best predicted reward of the Q-network
    envAct.step(action)
    state, reward, terminated, truncated, info = envObserve.step(action)
    state = state[np.newaxis]
    if terminated or truncated:
        state, info = envObserve.reset()
        envAct.reset()
        state = state[np.newaxis]

envAct.close()
envObserve.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[59], line 2
#       1 envObserve = gym.wrappers.AtariPreprocessing(gym.make("ALE/Frogger-v5", repeat_action_probability= 0), frame_skip = 1, noop_max= 0)
# ----> 2 envAct = gym.make("ALE/Frogger-v5", render_mode = "human", repeat_action_probability= 0)
#       3 envAct.reset()
#       4 state, info = envObserve.reset()
#
# File ~/miniconda3/envs/deepl/lib/python3.11/site-packages/gymnasium/envs/registration.py:802, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     799     render_mode = None
#     801 try:
# --> 802     env = env_creator(**env_spec_kwargs)
#     803 except TypeError as e:
#     804     if (
#     805         str(e).find("got an unexpected keyword argument 'render_mode'") >= 0
#     806         and apply_human_rendering
#     807     ):
#
# ...
